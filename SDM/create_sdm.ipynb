# %% [markdown]
# # SDM Aanmaken

# %%
import sqlite3
from pathlib import Path

SDM_PATH    = "../data/sdm_deproject.db"
SQL_SCRIPT  = "../data/sdm_create.sql"

# Verwijder de oude database
Path(SDM_PATH).unlink(missing_ok=True)
print(f"Oude database verwijderd: {SDM_PATH}")

# Maak een nieuwe aan met het SQL script
with open(SQL_SCRIPT, "r") as f:
    sql = f.read()

con = sqlite3.connect(SDM_PATH)
con.executescript(sql)
con.commit()

# Bevestiging
tables = con.execute("SELECT name FROM sqlite_master WHERE type='table' ORDER BY name").fetchall()
con.close()

print(f"\n✓ SDM aangemaakt met {len(tables)} tabellen:")
for t in tables:
    print(f"  {t[0]}")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[2], line 8
#       4 SDM_PATH    = "../data/sdm_deproject.db"
#       5 SQL_SCRIPT  = "../data/sdm_create.sql"
#       6
#       7 # Verwijder de oude database
# ----> 8 Path(SDM_PATH).unlink(missing_ok=True)
#       9 print(f"Oude database verwijderd: {SDM_PATH}")
#      10
#      11 # Maak een nieuwe aan met het SQL script
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\pathlib\_local.py:746, in Path.unlink(self, missing_ok)
#     741 """
#     742 Remove this file or link.
#     743 If the path is a directory, use rmdir() instead.
#     744 """
#     745 try:
# --> 746     os.unlink(self)
#     747 except FileNotFoundError:
#     748     if not missing_ok:
#
# PermissionError: [WinError 32] Het proces heeft geen toegang tot het bestand omdat het door een ander
# proces wordt gebruikt: '..\\data\\sdm_deproject.db'
